# %% [markdown]
# DATA FRAME
# a data frame is a object in pandas to represt a data in row and column format

# %%
#importing pandas library file
import pandas as pd

# %%
#to import the csv file into jupyter notebook
df = pd.read_csv(r"C:\Users\G.M.BHOOPESH\Desktop\ds\study materials\pandas\population.csv")
df
# Out:
#         period status  natural_increase  net_migration  population_change  \
# 0   30-06-2008      F            8500.0        -3200.0             4200.0
# 1   30-09-2008      F            8100.0         2900.0             9800.0
# 2   31-12-2008      F            9200.0         2700.0            10700.0
# 3   31-03-2009      F            9300.0         5100.0            13200.0
# 4   30-06-2009      F            8400.0         1900.0             9100.0
# 5   30-09-2009      F            8500.0         7400.0            14700.0
# 6   31-12-2009      F            9100.0         6900.0            14800.0
# 7   31-03-2010      F            9900.0         4800.0            13500.0
# 8   30-06-2010      F            8700.0        -2600.0             5000.0
# 9   30-09-2010      F            8400.0         4800.0            12000.0
# 10  31-12-2010      F            8900.0         3400.0            11200.0
# 11  31-03-2011      F            8800.0          900.0             8600.0
# ...

# %%
# to print first few rows 
df.head()
# Out:
#        period status  natural_increase  net_migration  population_change  \
# 0  30-06-2008      F            8500.0        -3200.0             4200.0
# 1  30-09-2008      F            8100.0         2900.0             9800.0
# 2  31-12-2008      F            9200.0         2700.0            10700.0
# 3  31-03-2009      F            9300.0         5100.0            13200.0
# 4  30-06-2009      F            8400.0         1900.0             9100.0
#
#    percent_population_change  population
# 0                       0.10   4259800.0
# 1                       0.23   4269600.0
# 2                       0.25   4280300.0
# 3                       0.31   4293500.0
# 4                       0.21   4302600.0

# %%
# to print first 2 rows 
df.head(2)
# Out:
#        period status  natural_increase  net_migration  population_change  \
# 0  30-06-2008      F            8500.0        -3200.0             4200.0
# 1  30-09-2008      F            8100.0         2900.0             9800.0
#
#    percent_population_change  population
# 0                       0.10   4259800.0
# 1                       0.23   4269600.0

# %%
# to primt last few rows 
df.tail()
# Out:
#         period status  natural_increase  net_migration  population_change  \
# 36  30-06-2017      F            6800.0        10500.0            17300.0
# 37  30-09-2017      F            5500.0        18500.0            24000.0
# 38  31-12-2017      F            7500.0        19100.0            26600.0
# 39  31-03-2018      F            7300.0        19900.0            27200.0
# 40  30-06-2018      P            6200.0         7500.0            13700.0
#
#     percent_population_change  population
# 36                       0.36   4793900.0
# 37                       0.50   4817800.0
# 38                       0.55   4844400.0
# 39                       0.56   4871600.0
# 40                       0.28   4885300.0

# %%
# to primt last 2 rows 
df.tail(2)
# Out:
#         period status  natural_increase  net_migration  population_change  \
# 39  31-03-2018      F            7300.0        19900.0            27200.0
# 40  30-06-2018      P            6200.0         7500.0            13700.0
#
#     percent_population_change  population
# 39                       0.56   4871600.0
# 40                       0.28   4885300.0

# %%
#slicing a dataframe by index
df[3:20]
# Out:
#         period status  natural_increase  net_migration  population_change  \
# 3   31-03-2009      F            9300.0         5100.0            13200.0
# 4   30-06-2009      F            8400.0         1900.0             9100.0
# 5   30-09-2009      F            8500.0         7400.0            14700.0
# 6   31-12-2009      F            9100.0         6900.0            14800.0
# 7   31-03-2010      F            9900.0         4800.0            13500.0
# 8   30-06-2010      F            8700.0        -2600.0             5000.0
# 9   30-09-2010      F            8400.0         4800.0            12000.0
# 10  31-12-2010      F            8900.0         3400.0            11200.0
# 11  31-03-2011      F            8800.0          900.0             8600.0
# 12  30-06-2011      F            7900.0        -5300.0             1500.0
# 13  30-09-2011      F            7500.0         1700.0             8100.0
# 14  31-12-2011      F            7800.0          800.0             7400.0
# ...

# %%
df.columns# to print all the columns
# Out:
# Index(['period', 'status', 'natural_increase', 'net_migration',
#        'population_change', 'percent_population_change', 'population'],
#       dtype='object')

# %%
df.status
# Out:
# 0     F
# 1     F
# 2     F
# 3     F
# 4     F
# 5     F
# 6     F
# 7     F
# 8     F
# 9     F
# 10    F
# 11    F
# 12    F
# 13    F
# 14    F
# 15    F
# 16    F
# 17    F
# 18    F
# 19    F
# 20    F
# 21    F
# 22    F
# 23    F
# 24    F
# 25    F
# 26    F
# 27    F
# 28    F
# 29    F
# 30    F
# 31    F
# 32    F
# 33    F
# 34    F
# 35    F
# 36    F
# 37    F
# 38    F
# 39    F
# 40    P
# Name: status, dtype: object

# %%
df[['status','period']] # to print only the required columns
# Out:
#    status      period
# 0       F  30-06-2008
# 1       F  30-09-2008
# 2       F  31-12-2008
# 3       F  31-03-2009
# 4       F  30-06-2009
# 5       F  30-09-2009
# 6       F  31-12-2009
# 7       F  31-03-2010
# 8       F  30-06-2010
# 9       F  30-09-2010
# 10      F  31-12-2010
# 11      F  31-03-2011
# 12      F  30-06-2011
# 13      F  30-09-2011
# 14      F  31-12-2011
# 15      F  31-03-2012
# 16      F  30-06-2012
# 17      F  30-09-2012
# 18      F  31-12-2012
# 19      F  31-03-2013
# 20      F  30-06-2013
# 21      F  30-09-2013
# 22      F  31-12-2013
# 23      F  31-03-2014
# 24      F  30-06-2014
# 25      F  30-09-2014
# 26      F  31-12-2014
# 27      F  31-03-2015
# 28      F  30-06-2015
# 29      F  30-09-2015
# 30      F  31-12-2015
# 31      F  31-03-2016
# 32      F  30-06-2016
# 33      F  30-09-2016
# 34      F  31-12-2016
# 35      F  31-03-2017
# 36      F  30-06-2017
# 37      F  30-09-2017
# 38      F  31-12-2017
# 39      F  31-03-2018
# ...

# %%
#operations using pandas
df.sum()#prints the sum of all the columns
# Out:
# period                       30-06-200830-09-200831-12-200831-03-200930-06-...
# status                               FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFP
# natural_increase                                                      316800.0
# net_migration                                                         337300.0
# population_change                                                     629800.0
# percent_population_change                                                13.82
# population                                                         184876900.0
# dtype: object

# %%
df['net_migration'].sum()#prints the sum of required the columns
# Out:
# 337300.0

# %%
df.describe()#describes the whole dataset with integer data
# Out:
#        natural_increase  net_migration  population_change  \
# count         41.000000      41.000000          41.000000
# mean        7726.829268    8226.829268       15360.975610
# std          985.399510    8082.481809        8098.236785
# min         5500.000000   -5300.000000        1500.000000
# 25%         7100.000000    1900.000000        9100.000000
# 50%         7600.000000    6900.000000       13800.000000
# 75%         8500.000000   16000.000000       23000.000000
# max         9900.000000   21900.000000       29400.000000
#
#        percent_population_change    population
# count                  41.000000  4.100000e+01
# mean                    0.337073  4.509193e+06
# std                     0.168971  1.851831e+05
# min                     0.030000  4.259800e+06
# 25%                     0.210000  4.373900e+06
# 50%                     0.310000  4.442100e+06
# 75%                     0.500000  4.647300e+06
# max                     0.620000  4.885300e+06

# %%
df['net_migration'].min()#prints the min element of required the columns
# Out:
# -5300.0

# %%
df['net_migration'].mean()#prints the mean of required the columns
# Out:
# 8226.829268292682

# %%
df['net_migration'].std()#prints the standard deviation of required the columns
# Out:
# 8082.481809142657

# %%
df['net_migration'].max()#prints the maximum element of required the columns
# Out:
# 21900.0

# %%
#to conditonally print rows and colunmns
    #for filtering columns                                 #for filtering rows
df[['period','status','natural_increase','net_migration']][df.natural_increase>=6500]
#it prints the following columns where the natural increase is greater than or equal to 6500
# Out:
#         period status  natural_increase  net_migration
# 0   30-06-2008      F            8500.0        -3200.0
# 1   30-09-2008      F            8100.0         2900.0
# 2   31-12-2008      F            9200.0         2700.0
# 3   31-03-2009      F            9300.0         5100.0
# 4   30-06-2009      F            8400.0         1900.0
# 5   30-09-2009      F            8500.0         7400.0
# 6   31-12-2009      F            9100.0         6900.0
# 7   31-03-2010      F            9900.0         4800.0
# 8   30-06-2010      F            8700.0        -2600.0
# 9   30-09-2010      F            8400.0         4800.0
# 10  31-12-2010      F            8900.0         3400.0
# 11  31-03-2011      F            8800.0          900.0
# 12  30-06-2011      F            7900.0        -5300.0
# 13  30-09-2011      F            7500.0         1700.0
# 14  31-12-2011      F            7800.0          800.0
# 15  31-03-2012      F            8800.0         -600.0
# ...

# %%
#index
#it is the first column in every table that numbers every rows in the table just like s.no 
#In pandas any of the columns can be set as a index and those can be used to acess rows

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\G.M.BHOOPESH\Desktop\ds\study materials\pandas\population.csv")

# %%
#it sets index as period and inplace modifies the table
df.set_index('period',inplace=True)
df
# Out:
#            status  natural_increase  net_migration  population_change  \
# period
# 30-06-2008      F            8500.0        -3200.0             4200.0
# 30-09-2008      F            8100.0         2900.0             9800.0
# 31-12-2008      F            9200.0         2700.0            10700.0
# 31-03-2009      F            9300.0         5100.0            13200.0
# 30-06-2009      F            8400.0         1900.0             9100.0
# 30-09-2009      F            8500.0         7400.0            14700.0
# 31-12-2009      F            9100.0         6900.0            14800.0
# 31-03-2010      F            9900.0         4800.0            13500.0
# 30-06-2010      F            8700.0        -2600.0             5000.0
# 30-09-2010      F            8400.0         4800.0            12000.0
# 31-12-2010      F            8900.0         3400.0            11200.0
# 31-03-2011      F            8800.0          900.0             8600.0
# ...

# %%
#acessing row using period as a index
df.loc['31-03-2018']
# Out:
# status                               F
# natural_increase                7300.0
# net_migration                  19900.0
# population_change              27200.0
# percent_population_change         0.56
# population                   4871600.0
# Name: 31-03-2018, dtype: object

# %%
#resetting the table
df.reset_index('period',inplace=True)
df
# Out:
#         period status  natural_increase  net_migration  population_change  \
# 0   30-06-2008      F            8500.0        -3200.0             4200.0
# 1   30-09-2008      F            8100.0         2900.0             9800.0
# 2   31-12-2008      F            9200.0         2700.0            10700.0
# 3   31-03-2009      F            9300.0         5100.0            13200.0
# 4   30-06-2009      F            8400.0         1900.0             9100.0
# 5   30-09-2009      F            8500.0         7400.0            14700.0
# 6   31-12-2009      F            9100.0         6900.0            14800.0
# 7   31-03-2010      F            9900.0         4800.0            13500.0
# 8   30-06-2010      F            8700.0        -2600.0             5000.0
# 9   30-09-2010      F            8400.0         4800.0            12000.0
# 10  31-12-2010      F            8900.0         3400.0            11200.0
# 11  31-03-2011      F            8800.0          900.0             8600.0
# ...

# %% [markdown]
# DIFFRENT WAYS OF CREATING A DATAFRAME
# 1.CSV
# 2.excel
# 3.python dictonary
# 4.list
# 5.list of dictionary

# %% [markdown]
# 1.reading data from a csv file
# import pandas as pd
# df = read_csv("population.csv")  (if the csv file is on the same folder as jupyter)
# df = read_csv(r"C:\Users\G.M.BHOOPESH\Downloads\population.csv") (if the csv file is on the computer somewhere else)
#
#
# 2.reading a xlsx file (xl file)
# import pandas as pd
# df = read_xlsx("population.xlsx","sheet1") (sheet name should be specified to refer in which the table is present)
#
#
# 3.python dictionary
# create a dictionary
# df = df.DataFrame (pass the dictionary name as a argument)
#
#
# 4.list
# create list
# df = df.DataFrame(pass the dictionary name as a argument,columns=[specify the column names])
#
#
# 5.list of dictionary
# create a dictionary list
# df = df.DataFrame (pass the dictionary list name as a argument)

# %% [markdown]
# READING AND WRITING EXCEL FILES
# 1.read.csv
# 2.write.csv
# 3.read.xlsx
# 4.write.xlsx

# %%
#to read a csv file
import pandas as pd
df = pd.read_csv(r"C:\Users\G.M.BHOOPESH\Desktop\ds\study materials\pandas\population.csv")
df
# Out:
#         period status  natural_increase  net_migration  population_change  \
# 0   30-06-2008      F            8500.0        -3200.0             4200.0
# 1   30-09-2008      F            8100.0         2900.0             9800.0
# 2   31-12-2008      F            9200.0         2700.0            10700.0
# 3   31-03-2009      F            9300.0         5100.0            13200.0
# 4   30-06-2009      F            8400.0         1900.0             9100.0
# 5   30-09-2009      F            8500.0         7400.0            14700.0
# 6   31-12-2009      F            9100.0         6900.0            14800.0
# 7   31-03-2010      F            9900.0         4800.0            13500.0
# 8   30-06-2010      F            8700.0        -2600.0             5000.0
# 9   30-09-2010      F            8400.0         4800.0            12000.0
# 10  31-12-2010      F            8900.0         3400.0            11200.0
# 11  31-03-2011      F            8800.0          900.0             8600.0
# ...

# %%
#to start the header for the first column
import pandas as pd
df = pd.read_csv(r"C:\Users\G.M.BHOOPESH\Desktop\ds\study materials\pandas\population.csv",header=1)
df
# Out:
#     30-06-2008  F    8500    -3200     4200   0.1    4259800
# 0   30-09-2008  F  8100.0   2900.0   9800.0  0.23  4269600.0
# 1   31-12-2008  F  9200.0   2700.0  10700.0  0.25  4280300.0
# 2   31-03-2009  F  9300.0   5100.0  13200.0  0.31  4293500.0
# 3   30-06-2009  F  8400.0   1900.0   9100.0  0.21  4302600.0
# 4   30-09-2009  F  8500.0   7400.0  14700.0  0.34  4317300.0
# 5   31-12-2009  F  9100.0   6900.0  14800.0  0.34  4332100.0
# 6   31-03-2010  F  9900.0   4800.0  13500.0  0.31  4345700.0
# 7   30-06-2010  F  8700.0  -2600.0   5000.0  0.11  4350700.0
# 8   30-09-2010  F  8400.0   4800.0  12000.0  0.28  4362700.0
# 9   31-12-2010  F  8900.0   3400.0  11200.0  0.26  4373900.0
# 10  31-03-2011  F  8800.0    900.0   8600.0  0.20  4382500.0
# 11  30-06-2011  F  7900.0  -5300.0   1500.0  0.03  4380000.0
# 12  30-09-2011  F  7500.0   1700.0   8100.0  0.18  4390000.0
# 13  31-12-2011  F  7800.0    800.0   7400.0  0.17  4399400.0
# ...

# %%
#to change the nan and not applicable values to nan
import pandas as pd
df = pd.read_csv(r"C:\Users\G.M.BHOOPESH\Desktop\ds\study materials\pandas\population.csv",na_values=['na','not available'])
df
# Out:
#         period status  natural_increase  net_migration  population_change  \
# 0   30-06-2008      F            8500.0        -3200.0             4200.0
# 1   30-09-2008      F            8100.0         2900.0             9800.0
# 2   31-12-2008      F            9200.0         2700.0            10700.0
# 3   31-03-2009      F            9300.0         5100.0            13200.0
# 4   30-06-2009      F            8400.0         1900.0             9100.0
# 5   30-09-2009      F            8500.0         7400.0            14700.0
# 6   31-12-2009      F            9100.0         6900.0            14800.0
# 7   31-03-2010      F            9900.0         4800.0            13500.0
# 8   30-06-2010      F            8700.0        -2600.0             5000.0
# 9   30-09-2010      F            8400.0         4800.0            12000.0
# 10  31-12-2010      F            8900.0         3400.0            11200.0
# 11  31-03-2011      F            8800.0          900.0             8600.0
# ...

# %%
#to tell there is no header in a file
import pandas as pd
df = pd.read_csv(r"C:\Users\G.M.BHOOPESH\Desktop\ds\study materials\pandas\population.csv",header=None,na_values=['na','not available'])
df
# Out:
#              0       1                 2              3                  4  \
# 0       period  status  natural_increase  net_migration  population_change
# 1   30-06-2008       F              8500          -3200               4200
# 2   30-09-2008       F              8100           2900               9800
# 3   31-12-2008       F              9200           2700              10700
# 4   31-03-2009       F              9300           5100              13200
# 5   30-06-2009       F              8400           1900               9100
# 6   30-09-2009       F              8500           7400              14700
# 7   31-12-2009       F              9100           6900              14800
# 8   31-03-2010       F              9900           4800              13500
# 9   30-06-2010       F              8700          -2600           5.00E+03
# 10  30-09-2010       F              8400           4800           1.20E+04
# ...

# %%
#to change the header values
df = pd.read_csv(r"C:\Users\G.M.BHOOPESH\Desktop\ds\study materials\pandas\population.csv",names=["lalith","bhoopesh","abi","srini","kavin","yeashu","rohit"])
df
# Out:
#         lalith bhoopesh               abi          srini              kavin  \
# 0       period   status  natural_increase  net_migration  population_change
# 1   30-06-2008        F              8500          -3200               4200
# 2   30-09-2008        F              8100           2900               9800
# 3   31-12-2008        F              9200           2700              10700
# 4   31-03-2009        F              9300           5100              13200
# 5   30-06-2009        F              8400           1900               9100
# 6   30-09-2009        F              8500           7400              14700
# 7   31-12-2009        F              9100           6900              14800
# 8   31-03-2010        F              9900           4800              13500
# 9   30-06-2010        F              8700          -2600           5.00E+03
# 10  30-09-2010        F              8400           4800           1.20E+04
# ...

# %%
#to only change na and not applicable values in period and net migration column to nan
import pandas as pd
df = pd.read_csv(r"C:\Users\G.M.BHOOPESH\Desktop\ds\study materials\pandas\population.csv",na_values={'period':['na','not applicable'],
                                                                               'net_migration':['na','not applicable']
                                                                              })
df
# Out:
#         period status  natural_increase  net_migration  population_change  \
# 0   30-06-2008      F            8500.0        -3200.0             4200.0
# 1   30-09-2008      F            8100.0         2900.0             9800.0
# 2   31-12-2008      F            9200.0         2700.0            10700.0
# 3   31-03-2009      F            9300.0         5100.0            13200.0
# 4   30-06-2009      F            8400.0         1900.0             9100.0
# 5   30-09-2009      F            8500.0         7400.0            14700.0
# 6   31-12-2009      F            9100.0         6900.0            14800.0
# 7   31-03-2010      F            9900.0         4800.0            13500.0
# 8   30-06-2010      F            8700.0        -2600.0             5000.0
# 9   30-09-2010      F            8400.0         4800.0            12000.0
# 10  31-12-2010      F            8900.0         3400.0            11200.0
# 11  31-03-2011      F            8800.0          900.0             8600.0
# ...

# %%
#to write a csv file
df.to_csv("new.csv",header=False)

# %%
#to only write the following columns
df.to_csv("new.csv",columns=["period","population"])
